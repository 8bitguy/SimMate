# %%
# %matplotlib inline
# Out:
# /Users/israelcastilloh/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
t=np.arange(0,200)
y = t**2

# %%
plt.plot(t,y)

# %%
t=np.arange(0,200)
f = 100*((t**2+10*t+100)/(t**2+20*t+100))

# %%
plt.plot(t,f)
